# %%
import pandas as pd
import numpy as np

a=pd.read_csv('bitcoin_price_1week_Test - Test.csv')
print(a.head())
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 0  Aug 07, 2017  3212.78  3397.68  3180.89  3378.94  1,482,280,000
# 1  Aug 06, 2017  3257.61  3293.29  3155.60  3213.94  1,105,030,000
# 2  Aug 05, 2017  2897.63  3290.01  2874.83  3252.91  1,945,700,000
# 3  Aug 04, 2017  2806.93  2899.33  2743.72  2895.89  1,002,120,000
# 4  Aug 03, 2017  2709.56  2813.31  2685.14  2804.73    804,797,000
#
#        Market Cap
# 0  52,987,300,000
# 1  53,720,900,000
# 2  47,778,200,000
# 3  46,276,200,000
# 4  44,666,400,000

# %%
print("type:",type(a))
print("columns:",list(a.columns))
print("index:",a.index.tolist())
# Out:
# type: <class 'pandas.DataFrame'>
# columns: ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap']
# index: [0, 1, 2, 3, 4, 5, 6]

# %%
b=pd.read_excel('Online_Retail.xlsx')
print(b.head())
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
print("first three rows:")
display(a.head(3))

print("\nlast three rows:")
display(a.tail(3))

print("\nInfo:")
a.info()

print("\nDescribe:")
display(a.describe())

print("\nShape of the DataFrame:", a.shape)
# Out:
# first three rows:
#            Date     Open     High      Low    Close         Volume  \
# 0  Aug 07, 2017  3212.78  3397.68  3180.89  3378.94  1,482,280,000
# 1  Aug 06, 2017  3257.61  3293.29  3155.60  3213.94  1,105,030,000
# 2  Aug 05, 2017  2897.63  3290.01  2874.83  3252.91  1,945,700,000
#
#        Market Cap
# 0  52,987,300,000
# 1  53,720,900,000
# 2  47,778,200,000
# last three rows:
#            Date     Open     High      Low    Close         Volume  \
# 4  Aug 03, 2017  2709.56  2813.31  2685.14  2804.73    804,797,000
# 5  Aug 02, 2017  2727.13  2762.53  2668.59  2710.67  1,094,950,000
# 6  Aug 01, 2017  2871.30  2921.35  2685.61  2718.26  1,324,670,000
#
#        Market Cap
# 4  44,666,400,000
# 5  44,950,800,000
# 6  47,321,800,000
# Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        7 non-null      str
# ...

# %%
print("First 3 rows:")
display(b.head(3))

print("\nLast 3 rows:")
display(b.tail(3))

print("\nInfo:")
b.info()

print("\nDescribe:")
display(b.describe())

print("\nShape (rows, columns):", b.shape)
# Out:
# First 3 rows:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# Last 3 rows:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# ...

# %%
print("loc example (rows 0-2 ,specific columns): ")
display(b.loc[0:2,["InvoiceNo","StockCode","Description"]])

print("\niloc example (first 3 rows,first 3 columns): ")
display(b.iloc[0:3, 0:3])
# Out:
# loc example (rows 0-2 ,specific columns):
#   InvoiceNo StockCode                         Description
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365     71053                 WHITE METAL LANTERN
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER
# iloc example (first 3 rows,first 3 columns):
#   InvoiceNo StockCode                         Description
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# 1    536365     71053                 WHITE METAL LANTERN
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER

# %%
print(a.head())
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 0  Aug 07, 2017  3212.78  3397.68  3180.89  3378.94  1,482,280,000
# 1  Aug 06, 2017  3257.61  3293.29  3155.60  3213.94  1,105,030,000
# 2  Aug 05, 2017  2897.63  3290.01  2874.83  3252.91  1,945,700,000
# 3  Aug 04, 2017  2806.93  2899.33  2743.72  2895.89  1,002,120,000
# 4  Aug 03, 2017  2709.56  2813.31  2685.14  2804.73    804,797,000
#
#        Market Cap
# 0  52,987,300,000
# 1  53,720,900,000
# 2  47,778,200,000
# 3  46,276,200,000
# 4  44,666,400,000

# %%
print("loc example (rows 0-2, specific columns):")
display(a.loc[0:2, ["Date", "Open", "High"]])

# iloc: position-based selection
print("\niloc example (first 3 rows, first 3 columns):")
display(a.iloc[0:3, 0:3])
# Out:
# loc example (rows 0-2, specific columns):
#            Date     Open     High
# 0  Aug 07, 2017  3212.78  3397.68
# 1  Aug 06, 2017  3257.61  3293.29
# 2  Aug 05, 2017  2897.63  3290.01
# iloc example (first 3 rows, first 3 columns):
#            Date     Open     High
# 0  Aug 07, 2017  3212.78  3397.68
# 1  Aug 06, 2017  3257.61  3293.29
# 2  Aug 05, 2017  2897.63  3290.01
